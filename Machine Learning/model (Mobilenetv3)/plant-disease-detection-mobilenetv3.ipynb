# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from keras.layers import Conv2D,MaxPool2D,AveragePooling2D,Dense,Flatten,ZeroPadding2D,BatchNormalization,Activation,Add,Input,Dropout,GlobalAveragePooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import os
import shutil
import random

# %% [markdown]
# ## Preparing the Dataset

# %%
base_dir = "../input/new-plant-diseases-dataset/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)"
image_size = (224,224)
train_dir = os.path.join(base_dir, "train")
valid_dir = os.path.join(base_dir, "valid")
test_dir = '/kaggle/input/new-plant-diseases-dataset/test/test'
# Define the new base directory structure
base_output_dir = '/kaggle/working/dataset'
output_train_dir = os.path.join(base_output_dir, 'train')
output_valid_dir = os.path.join(base_output_dir, 'valid')
output_test_dir = os.path.join(base_output_dir, 'test')

# Create the output directories
os.makedirs(output_train_dir, exist_ok=True)
os.makedirs(output_valid_dir, exist_ok=True)
os.makedirs(output_test_dir, exist_ok=True)

# Copy the training set
for class_folder in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_folder)
    if os.path.isdir(class_path):  # Ensure it's a directory
        # Create the class directory in the output train directory
        output_class_path = os.path.join(output_train_dir, class_folder)
        os.makedirs(output_class_path, exist_ok=True)
        
        # Copy all images to the new class directory
        for img_file in os.listdir(class_path):
            img_path = os.path.join(class_path, img_file)
            if os.path.isfile(img_path):  # Ensure it's a file
                shutil.copy(img_path, output_class_path)

# Copy the validation set
for class_folder in os.listdir(valid_dir):
    class_path = os.path.join(valid_dir, class_folder)
    if os.path.isdir(class_path):  # Ensure it's a directory
        # Create the class directory in the output valid directory
        output_class_path = os.path.join(output_valid_dir, class_folder)
        os.makedirs(output_class_path, exist_ok=True)
        
        # Copy all images to the new class directory
        for img_file in os.listdir(class_path):
            img_path = os.path.join(class_path, img_file)
            if os.path.isfile(img_path):  # Ensure it's a file
                shutil.copy(img_path, output_class_path)


print("Dataset has been reorganized and moved to /kaggle/working/dataset")
# Out:
# Dataset has been reorganized and moved to /kaggle/working/dataset

# %%
train_dir = '/kaggle/working/dataset/train'
valid_dir = '/kaggle/working/dataset/valid'
test_dir = '/kaggle/working/dataset/test'

os.makedirs(test_dir, exist_ok=True)

split_ratio = 0.2 


for class_name in os.listdir(valid_dir):
    class_valid_dir = os.path.join(valid_dir, class_name)
    class_test_dir = os.path.join(test_dir, class_name)

    os.makedirs(class_test_dir, exist_ok=True)

    images = [f for f in os.listdir(class_valid_dir) if os.path.isfile(os.path.join(class_valid_dir, f))]
    
    random.shuffle(images)
    num_test_images = int(len(images) * split_ratio)
    test_images = images[:num_test_images]

    for image in test_images:
        src_path = os.path.join(class_valid_dir, image)
        dest_path = os.path.join(class_test_dir, image)
        shutil.move(src_path, dest_path)

    print(f"Moved {len(test_images)} images from '{class_valid_dir}' to '{class_test_dir}'")
# Out:
# Moved 85 images from '/kaggle/working/dataset/valid/Tomato___Bacterial_spot' to '/kaggle/working/dataset/test/Tomato___Bacterial_spot'
# Moved 91 images from '/kaggle/working/dataset/valid/Potato___healthy' to '/kaggle/working/dataset/test/Potato___healthy'
# Moved 96 images from '/kaggle/working/dataset/valid/Tomato___Early_blight' to '/kaggle/working/dataset/test/Tomato___Early_blight'
# Moved 94 images from '/kaggle/working/dataset/valid/Tomato___Leaf_Mold' to '/kaggle/working/dataset/test/Tomato___Leaf_Mold'
# Moved 87 images from '/kaggle/working/dataset/valid/Tomato___Spider_mites Two-spotted_spider_mite' to '/kaggle/working/dataset/test/Tomato___Spider_mites Two-spotted_spider_mite'
# Moved 92 images from '/kaggle/working/dataset/valid/Tomato___Late_blight' to '/kaggle/working/dataset/test/Tomato___Late_blight'
# Moved 84 images from '/kaggle/working/dataset/valid/Grape___healthy' to '/kaggle/working/dataset/test/Grape___healthy'
# Moved 86 images from '/kaggle/working/dataset/valid/Squash___Powdery_mildew' to '/kaggle/working/dataset/test/Squash___Powdery_mildew'
# Moved 96 images from '/kaggle/working/dataset/valid/Grape___Esca_(Black_Measles)' to '/kaggle/working/dataset/test/Grape___Esca_(Black_Measles)'
# Moved 100 images from '/kaggle/working/dataset/valid/Orange___Haunglongbing_(Citrus_greening)' to '/kaggle/working/dataset/test/Orange___Haunglongbing_(Citrus_greening)'
# Moved 100 images from '/kaggle/working/dataset/valid/Apple___Apple_scab' to '/kaggle/working/dataset/test/Apple___Apple_scab'
# Moved 82 images from '/kaggle/working/dataset/valid/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot' to '/kaggle/working/dataset/test/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot'
# Moved 87 images from '/kaggle/working/dataset/valid/Tomato___Septoria_leaf_spot' to '/kaggle/working/dataset/test/Tomato___Septoria_leaf_spot'
# Moved 91 images from '/kaggle/working/dataset/valid/Strawberry___healthy' to '/kaggle/working/dataset/test/Strawberry___healthy'
# Moved 91 images from '/kaggle/working/dataset/valid/Tomato___Target_Spot' to '/kaggle/working/dataset/test/Tomato___Target_Spot'
# Moved 96 images from '/kaggle/working/dataset/valid/Tomato___healthy' to '/kaggle/working/dataset/test/Tomato___healthy'
# Moved 100 images from '/kaggle/working/dataset/valid/Apple___healthy' to '/kaggle/working/dataset/test/Apple___healthy'
# Moved 93 images from '/kaggle/working/dataset/valid/Corn_(maize)___healthy' to '/kaggle/working/dataset/test/Corn_(maize)___healthy'
# Moved 98 images from '/kaggle/working/dataset/valid/Tomato___Tomato_Yellow_Leaf_Curl_Virus' to '/kaggle/working/dataset/test/Tomato___Tomato_Yellow_Leaf_Curl_Virus'
# Moved 88 images from '/kaggle/working/dataset/valid/Apple___Cedar_apple_rust' to '/kaggle/working/dataset/test/Apple___Cedar_apple_rust'
# Moved 97 images from '/kaggle/working/dataset/valid/Potato___Early_blight' to '/kaggle/working/dataset/test/Potato___Early_blight'
# Moved 95 images from '/kaggle/working/dataset/valid/Corn_(maize)___Common_rust_' to '/kaggle/working/dataset/test/Corn_(maize)___Common_rust_'
# Moved 94 images from '/kaggle/working/dataset/valid/Grape___Black_rot' to '/kaggle/working/dataset/test/Grape___Black_rot'
# Moved 99 images from '/kaggle/working/dataset/valid/Apple___Black_rot' to '/kaggle/working/dataset/test/Apple___Black_rot'
# Moved 86 images from '/kaggle/working/dataset/valid/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)' to '/kaggle/working/dataset/test/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'
# Moved 97 images from '/kaggle/working/dataset/valid/Potato___Late_blight' to '/kaggle/working/dataset/test/Potato___Late_blight'
# Moved 95 images from '/kaggle/working/dataset/valid/Corn_(maize)___Northern_Leaf_Blight' to '/kaggle/working/dataset/test/Corn_(maize)___Northern_Leaf_Blight'
# Moved 99 images from '/kaggle/working/dataset/valid/Pepper,_bell___healthy' to '/kaggle/working/dataset/test/Pepper,_bell___healthy'
# Moved 91 images from '/kaggle/working/dataset/valid/Peach___Bacterial_spot' to '/kaggle/working/dataset/test/Peach___Bacterial_spot'
# Moved 86 images from '/kaggle/working/dataset/valid/Peach___healthy' to '/kaggle/working/dataset/test/Peach___healthy'
# Moved 95 images from '/kaggle/working/dataset/valid/Pepper,_bell___Bacterial_spot' to '/kaggle/working/dataset/test/Pepper,_bell___Bacterial_spot'
# Moved 89 images from '/kaggle/working/dataset/valid/Raspberry___healthy' to '/kaggle/working/dataset/test/Raspberry___healthy'
# Moved 84 images from '/kaggle/working/dataset/valid/Cherry_(including_sour)___Powdery_mildew' to '/kaggle/working/dataset/test/Cherry_(including_sour)___Powdery_mildew'
# Moved 88 images from '/kaggle/working/dataset/valid/Strawberry___Leaf_scorch' to '/kaggle/working/dataset/test/Strawberry___Leaf_scorch'
# Moved 91 images from '/kaggle/working/dataset/valid/Cherry_(including_sour)___healthy' to '/kaggle/working/dataset/test/Cherry_(including_sour)___healthy'
# Moved 101 images from '/kaggle/working/dataset/valid/Soybean___healthy' to '/kaggle/working/dataset/test/Soybean___healthy'
# Moved 89 images from '/kaggle/working/dataset/valid/Tomato___Tomato_mosaic_virus' to '/kaggle/working/dataset/test/Tomato___Tomato_mosaic_virus'
# Moved 90 images from '/kaggle/working/dataset/valid/Blueberry___healthy' to '/kaggle/working/dataset/test/Blueberry___healthy'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    color_mode='rgb',
    seed=42,
    class_mode='categorical'
)

# Load validation data
validation_generator = val_datagen.flow_from_directory(
    valid_dir,
    target_size=(224, 224),
    batch_size=32,
    color_mode='rgb',
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    color_mode='rgb',
    class_mode='categorical'
    shuffle=False
)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 14069 images belonging to 38 classes.
# Found 3503 images belonging to 38 classes.

# %% [markdown]
# ## Building The Model With MobileNetV3Large

# %%
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras import layers, models
import tensorflow as tf

base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  

x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = layers.Dropout(0.5)(x)
predictions = layers.Dense(38, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)

model = models.Model(inputs=base_model.input, outputs=predictions)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',   
    factor=0.5,           
    patience=3,           
    min_lr=1e-6           
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',   
    patience=5,            
    restore_best_weights=True 
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        144 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        256 │ re_lu[0][0]       │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 112, 112,  │          0 │ activation[0][0], │
# │ (Add)               │ 16)               │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │      1,024 │ expanded_conv_ad… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 112, 112,  │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 113, 113,  │          0 │ re_lu_1[0][0]     │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        576 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │      1,536 │ re_lu_2[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_1_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        648 │ re_lu_3[0][0]     │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │      1,728 │ re_lu_4[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_2_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 59, 59,    │          0 │ re_lu_5[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │      1,800 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      1,752 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │      1,800 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 72)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 1, 1, 72)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 1, 72)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 28, 28,    │          0 │ re_lu_6[0][0],    │
# │ (Multiply)          │ 72)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │      2,880 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_3_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │      3,000 │ re_lu_8[0][0]     │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │          0 │ re_lu_9[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 1, 120) │          0 │ re_lu_10[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 28, 28,    │          0 │ re_lu_9[0][0],    │
# │ (Multiply)          │ 120)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │      3,000 │ re_lu_11[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │          0 │ re_lu_12[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 1, 1, 120) │          0 │ re_lu_13[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 28, 28,    │          0 │ re_lu_12[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 28, 28,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 29, 29,    │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      2,160 │ expanded_conv_6_… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │     19,200 │ activation_2[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        320 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │     16,000 │ expanded_conv_6_… │
# │ (Conv2D)            │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,800 │ activation_3[0][… │
# │ (DepthwiseConv2D)   │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │     16,000 │ activation_4[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        320 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 80)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_7_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │      1,656 │ activation_5[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │     14,720 │ activation_6[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │        320 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_add │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Add)               │ 80)               │            │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_8_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │      1,656 │ activation_7[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │     14,720 │ activation_8[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │        320 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Add)               │ 80)               │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │     38,400 │ expanded_conv_9_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      4,320 │ activation_9[0][… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │          0 │ activation_10[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │     57,720 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │     58,080 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 480) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 1, 1, 480) │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 1, 1, 480) │          0 │ re_lu_14[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 14, 14,    │          0 │ activation_10[0]… │
# │ (Multiply)          │ 480)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │     53,760 │ expanded_conv_10… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │        448 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_10… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      6,048 │ activation_11[0]… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │          0 │ activation_12[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_11… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 1, 1, 672) │          0 │ re_lu_15[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 14, 14,    │          0 │ activation_12[0]… │
# │ (Multiply)          │ 672)              │            │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │        448 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_a… │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Add)               │ 112)              │            │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 14, 14,    │          0 │ expanded_conv_12… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 17, 17,    │          0 │ activation_13[0]… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │     16,800 │ expanded_conv_12… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 672) │          0 │ expanded_conv_12… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │          0 │ activation_14[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_12… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 1, 1, 672) │          0 │ re_lu_16[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 7, 7, 672) │          0 │ activation_14[0]… │
# │ (Multiply)          │                   │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │    107,520 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │     24,000 │ activation_15[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │          0 │ activation_16[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_13… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 1, 1, 960) │          0 │ re_lu_17[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 7, 7, 960) │          0 │ activation_16[0]… │
# │ (Multiply)          │                   │            │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_12… │
# │ (Add)               │                   │            │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │     24,000 │ activation_17[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │          0 │ activation_18[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_14… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 1, 1, 960) │          0 │ re_lu_18[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 7, 7, 960) │          0 │ activation_18[0]… │
# │ (Multiply)          │                   │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_13… │
# │ (Add)               │                   │            │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 960) │    153,600 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 960) │      3,840 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 7, 7, 960) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 960)       │          0 │ activation_19[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 960)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    492,032 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 38)        │     19,494 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,507,878 (13.38 MB)
#  Trainable params: 511,526 (1.95 MB)
#  Non-trainable params: 2,996,352 (11.43 MB)

# %% [markdown]
# ### Training for 130 epochs

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=130,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/130
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731660544.531990     153 service.cc:145] XLA service 0x79d3a8002e60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731660544.532063     153 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#    4/2197 ━━━━━━━━━━━━━━━━━━━━ 1:43 47ms/step - accuracy: 0.0391 - loss: 5.8409
# I0000 00:00:1731660553.041975     153 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 144s 59ms/step - accuracy: 0.0537 - loss: 5.2700 - val_accuracy: 0.5235 - val_loss: 3.1642 - learning_rate: 1.0000e-05
# Epoch 2/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.2212 - loss: 3.6532 - val_accuracy: 0.6993 - val_loss: 2.4699 - learning_rate: 1.0000e-05
# Epoch 3/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 113s 51ms/step - accuracy: 0.3748 - loss: 2.9519 - val_accuracy: 0.7817 - val_loss: 1.9330 - learning_rate: 1.0000e-05
# Epoch 4/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.4825 - loss: 2.4994 - val_accuracy: 0.8251 - val_loss: 1.5815 - learning_rate: 1.0000e-05
# Epoch 5/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.5564 - loss: 2.1933 - val_accuracy: 0.8541 - val_loss: 1.3601 - learning_rate: 1.0000e-05
# Epoch 6/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.6105 - loss: 1.9597 - val_accuracy: 0.8706 - val_loss: 1.2194 - learning_rate: 1.0000e-05
# Epoch 7/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 103s 47ms/step - accuracy: 0.6433 - loss: 1.8150 - val_accuracy: 0.8842 - val_loss: 1.1199 - learning_rate: 1.0000e-05
# Epoch 8/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.6749 - loss: 1.6859 - val_accuracy: 0.8938 - val_loss: 1.0465 - learning_rate: 1.0000e-05
# Epoch 9/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 103s 47ms/step - accuracy: 0.6994 - loss: 1.5794 - val_accuracy: 0.9014 - val_loss: 0.9873 - learning_rate: 1.0000e-05
# Epoch 10/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.7149 - loss: 1.5012 - val_accuracy: 0.9072 - val_loss: 0.9412 - learning_rate: 1.0000e-05
# Epoch 11/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.7384 - loss: 1.4262 - val_accuracy: 0.9119 - val_loss: 0.9029 - learning_rate: 1.0000e-05
# Epoch 12/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.7493 - loss: 1.3705 - val_accuracy: 0.9156 - val_loss: 0.8682 - learning_rate: 1.0000e-05
# Epoch 13/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.7598 - loss: 1.3149 - val_accuracy: 0.9198 - val_loss: 0.8385 - learning_rate: 1.0000e-05
# Epoch 14/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.7707 - loss: 1.2761 - val_accuracy: 0.9237 - val_loss: 0.8118 - learning_rate: 1.0000e-05
# Epoch 15/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.7838 - loss: 1.2177 - val_accuracy: 0.9270 - val_loss: 0.7873 - learning_rate: 1.0000e-05
# Epoch 16/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.7905 - loss: 1.1887 - val_accuracy: 0.9308 - val_loss: 0.7655 - learning_rate: 1.0000e-05
# Epoch 17/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.7965 - loss: 1.1566 - val_accuracy: 0.9316 - val_loss: 0.7469 - learning_rate: 1.0000e-05
# Epoch 18/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.7998 - loss: 1.1240 - val_accuracy: 0.9350 - val_loss: 0.7284 - learning_rate: 1.0000e-05
# Epoch 19/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.8093 - loss: 1.0922 - val_accuracy: 0.9357 - val_loss: 0.7122 - learning_rate: 1.0000e-05
# Epoch 20/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8135 - loss: 1.0645 - val_accuracy: 0.9378 - val_loss: 0.6957 - learning_rate: 1.0000e-05
# Epoch 21/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8165 - loss: 1.0454 - val_accuracy: 0.9399 - val_loss: 0.6798 - learning_rate: 1.0000e-05
# Epoch 22/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.8253 - loss: 1.0203 - val_accuracy: 0.9412 - val_loss: 0.6670 - learning_rate: 1.0000e-05
# Epoch 23/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.8262 - loss: 0.9988 - val_accuracy: 0.9429 - val_loss: 0.6535 - learning_rate: 1.0000e-05
# Epoch 24/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8296 - loss: 0.9801 - val_accuracy: 0.9429 - val_loss: 0.6431 - learning_rate: 1.0000e-05
# Epoch 25/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 103s 47ms/step - accuracy: 0.8305 - loss: 0.9694 - val_accuracy: 0.9454 - val_loss: 0.6299 - learning_rate: 1.0000e-05
# Epoch 26/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8379 - loss: 0.9425 - val_accuracy: 0.9460 - val_loss: 0.6183 - learning_rate: 1.0000e-05
# Epoch 27/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8421 - loss: 0.9196 - val_accuracy: 0.9468 - val_loss: 0.6077 - learning_rate: 1.0000e-05
# Epoch 28/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8431 - loss: 0.9128 - val_accuracy: 0.9475 - val_loss: 0.5971 - learning_rate: 1.0000e-05
# Epoch 29/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.8435 - loss: 0.8989 - val_accuracy: 0.9481 - val_loss: 0.5891 - learning_rate: 1.0000e-05
# Epoch 30/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.8490 - loss: 0.8771 - val_accuracy: 0.9502 - val_loss: 0.5783 - learning_rate: 1.0000e-05
# Epoch 31/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 136s 48ms/step - accuracy: 0.8502 - loss: 0.8638 - val_accuracy: 0.9497 - val_loss: 0.5713 - learning_rate: 1.0000e-05
# Epoch 32/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 51ms/step - accuracy: 0.8554 - loss: 0.8488 - val_accuracy: 0.9510 - val_loss: 0.5618 - learning_rate: 1.0000e-05
# Epoch 33/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8540 - loss: 0.8441 - val_accuracy: 0.9520 - val_loss: 0.5528 - learning_rate: 1.0000e-05
# Epoch 34/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8559 - loss: 0.8309 - val_accuracy: 0.9528 - val_loss: 0.5453 - learning_rate: 1.0000e-05
# Epoch 35/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.8588 - loss: 0.8128 - val_accuracy: 0.9532 - val_loss: 0.5386 - learning_rate: 1.0000e-05
# Epoch 36/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.8596 - loss: 0.8126 - val_accuracy: 0.9533 - val_loss: 0.5316 - learning_rate: 1.0000e-05
# Epoch 37/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.8590 - loss: 0.7993 - val_accuracy: 0.9540 - val_loss: 0.5246 - learning_rate: 1.0000e-05
# Epoch 38/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 48ms/step - accuracy: 0.8638 - loss: 0.7835 - val_accuracy: 0.9550 - val_loss: 0.5174 - learning_rate: 1.0000e-05
# Epoch 39/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8621 - loss: 0.7863 - val_accuracy: 0.9540 - val_loss: 0.5125 - learning_rate: 1.0000e-05
# Epoch 40/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8632 - loss: 0.7753 - val_accuracy: 0.9551 - val_loss: 0.5061 - learning_rate: 1.0000e-05
# Epoch 41/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8682 - loss: 0.7631 - val_accuracy: 0.9566 - val_loss: 0.4994 - learning_rate: 1.0000e-05
# Epoch 42/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 144s 49ms/step - accuracy: 0.8700 - loss: 0.7493 - val_accuracy: 0.9566 - val_loss: 0.4942 - learning_rate: 1.0000e-05
# Epoch 43/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8695 - loss: 0.7453 - val_accuracy: 0.9564 - val_loss: 0.4884 - learning_rate: 1.0000e-05
# Epoch 44/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 113s 51ms/step - accuracy: 0.8709 - loss: 0.7383 - val_accuracy: 0.9573 - val_loss: 0.4837 - learning_rate: 1.0000e-05
# Epoch 45/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8712 - loss: 0.7308 - val_accuracy: 0.9585 - val_loss: 0.4770 - learning_rate: 1.0000e-05
# Epoch 46/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8755 - loss: 0.7203 - val_accuracy: 0.9586 - val_loss: 0.4724 - learning_rate: 1.0000e-05
# Epoch 47/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8727 - loss: 0.7177 - val_accuracy: 0.9582 - val_loss: 0.4685 - learning_rate: 1.0000e-05
# Epoch 48/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 112s 51ms/step - accuracy: 0.8737 - loss: 0.7115 - val_accuracy: 0.9593 - val_loss: 0.4636 - learning_rate: 1.0000e-05
# Epoch 49/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8742 - loss: 0.7055 - val_accuracy: 0.9589 - val_loss: 0.4595 - learning_rate: 1.0000e-05
# Epoch 50/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8763 - loss: 0.6985 - val_accuracy: 0.9590 - val_loss: 0.4553 - learning_rate: 1.0000e-05
# Epoch 51/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8782 - loss: 0.6897 - val_accuracy: 0.9595 - val_loss: 0.4507 - learning_rate: 1.0000e-05
# Epoch 52/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.8796 - loss: 0.6847 - val_accuracy: 0.9603 - val_loss: 0.4473 - learning_rate: 1.0000e-05
# Epoch 53/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8803 - loss: 0.6816 - val_accuracy: 0.9596 - val_loss: 0.4436 - learning_rate: 1.0000e-05
# Epoch 54/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8799 - loss: 0.6764 - val_accuracy: 0.9605 - val_loss: 0.4393 - learning_rate: 1.0000e-05
# Epoch 55/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 48ms/step - accuracy: 0.8807 - loss: 0.6667 - val_accuracy: 0.9613 - val_loss: 0.4349 - learning_rate: 1.0000e-05
# Epoch 56/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8797 - loss: 0.6676 - val_accuracy: 0.9603 - val_loss: 0.4320 - learning_rate: 1.0000e-05
# Epoch 57/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8809 - loss: 0.6603 - val_accuracy: 0.9616 - val_loss: 0.4276 - learning_rate: 1.0000e-05
# Epoch 58/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.8870 - loss: 0.6508 - val_accuracy: 0.9619 - val_loss: 0.4248 - learning_rate: 1.0000e-05
# Epoch 59/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.8818 - loss: 0.6528 - val_accuracy: 0.9623 - val_loss: 0.4209 - learning_rate: 1.0000e-05
# Epoch 60/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8864 - loss: 0.6421 - val_accuracy: 0.9624 - val_loss: 0.4179 - learning_rate: 1.0000e-05
# Epoch 61/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 103s 47ms/step - accuracy: 0.8831 - loss: 0.6428 - val_accuracy: 0.9625 - val_loss: 0.4149 - learning_rate: 1.0000e-05
# Epoch 62/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8870 - loss: 0.6311 - val_accuracy: 0.9625 - val_loss: 0.4125 - learning_rate: 1.0000e-05
# Epoch 63/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 48ms/step - accuracy: 0.8883 - loss: 0.6278 - val_accuracy: 0.9630 - val_loss: 0.4094 - learning_rate: 1.0000e-05
# Epoch 64/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.8889 - loss: 0.6243 - val_accuracy: 0.9645 - val_loss: 0.4054 - learning_rate: 1.0000e-05
# Epoch 65/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8862 - loss: 0.6236 - val_accuracy: 0.9638 - val_loss: 0.4035 - learning_rate: 1.0000e-05
# Epoch 66/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8866 - loss: 0.6260 - val_accuracy: 0.9635 - val_loss: 0.4011 - learning_rate: 1.0000e-05
# Epoch 67/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.8909 - loss: 0.6111 - val_accuracy: 0.9636 - val_loss: 0.3982 - learning_rate: 1.0000e-05
# Epoch 68/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8896 - loss: 0.6130 - val_accuracy: 0.9636 - val_loss: 0.3964 - learning_rate: 1.0000e-05
# Epoch 69/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8916 - loss: 0.6041 - val_accuracy: 0.9645 - val_loss: 0.3934 - learning_rate: 1.0000e-05
# Epoch 70/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 48ms/step - accuracy: 0.8920 - loss: 0.6041 - val_accuracy: 0.9647 - val_loss: 0.3908 - learning_rate: 1.0000e-05
# Epoch 71/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8917 - loss: 0.5980 - val_accuracy: 0.9645 - val_loss: 0.3884 - learning_rate: 1.0000e-05
# Epoch 72/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 113s 51ms/step - accuracy: 0.8910 - loss: 0.5960 - val_accuracy: 0.9647 - val_loss: 0.3859 - learning_rate: 1.0000e-05
# Epoch 73/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8897 - loss: 0.5986 - val_accuracy: 0.9652 - val_loss: 0.3841 - learning_rate: 1.0000e-05
# Epoch 74/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8932 - loss: 0.5873 - val_accuracy: 0.9652 - val_loss: 0.3830 - learning_rate: 1.0000e-05
# Epoch 75/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8948 - loss: 0.5868 - val_accuracy: 0.9653 - val_loss: 0.3804 - learning_rate: 1.0000e-05
# Epoch 76/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.8929 - loss: 0.5851 - val_accuracy: 0.9655 - val_loss: 0.3780 - learning_rate: 1.0000e-05
# Epoch 77/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8943 - loss: 0.5836 - val_accuracy: 0.9653 - val_loss: 0.3754 - learning_rate: 1.0000e-05
# Epoch 78/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8961 - loss: 0.5762 - val_accuracy: 0.9657 - val_loss: 0.3734 - learning_rate: 1.0000e-05
# Epoch 79/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 48ms/step - accuracy: 0.8945 - loss: 0.5759 - val_accuracy: 0.9652 - val_loss: 0.3718 - learning_rate: 1.0000e-05
# Epoch 80/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8951 - loss: 0.5723 - val_accuracy: 0.9657 - val_loss: 0.3701 - learning_rate: 1.0000e-05
# Epoch 81/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8946 - loss: 0.5712 - val_accuracy: 0.9659 - val_loss: 0.3690 - learning_rate: 1.0000e-05
# Epoch 82/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.8952 - loss: 0.5709 - val_accuracy: 0.9656 - val_loss: 0.3675 - learning_rate: 1.0000e-05
# Epoch 83/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 48ms/step - accuracy: 0.8975 - loss: 0.5643 - val_accuracy: 0.9657 - val_loss: 0.3652 - learning_rate: 1.0000e-05
# Epoch 84/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9000 - loss: 0.5598 - val_accuracy: 0.9660 - val_loss: 0.3637 - learning_rate: 1.0000e-05
# Epoch 85/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8970 - loss: 0.5637 - val_accuracy: 0.9667 - val_loss: 0.3619 - learning_rate: 1.0000e-05
# Epoch 86/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8998 - loss: 0.5536 - val_accuracy: 0.9672 - val_loss: 0.3601 - learning_rate: 1.0000e-05
# Epoch 87/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.9008 - loss: 0.5505 - val_accuracy: 0.9660 - val_loss: 0.3586 - learning_rate: 1.0000e-05
# Epoch 88/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8970 - loss: 0.5538 - val_accuracy: 0.9666 - val_loss: 0.3579 - learning_rate: 1.0000e-05
# Epoch 89/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.8996 - loss: 0.5507 - val_accuracy: 0.9660 - val_loss: 0.3562 - learning_rate: 1.0000e-05
# Epoch 90/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8985 - loss: 0.5469 - val_accuracy: 0.9665 - val_loss: 0.3549 - learning_rate: 1.0000e-05
# Epoch 91/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8995 - loss: 0.5477 - val_accuracy: 0.9665 - val_loss: 0.3536 - learning_rate: 1.0000e-05
# Epoch 92/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 113s 51ms/step - accuracy: 0.9030 - loss: 0.5373 - val_accuracy: 0.9665 - val_loss: 0.3529 - learning_rate: 1.0000e-05
# Epoch 93/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 135s 48ms/step - accuracy: 0.9014 - loss: 0.5406 - val_accuracy: 0.9665 - val_loss: 0.3513 - learning_rate: 1.0000e-05
# Epoch 94/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.8993 - loss: 0.5426 - val_accuracy: 0.9669 - val_loss: 0.3493 - learning_rate: 1.0000e-05
# Epoch 95/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.9027 - loss: 0.5380 - val_accuracy: 0.9677 - val_loss: 0.3481 - learning_rate: 1.0000e-05
# Epoch 96/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.9034 - loss: 0.5301 - val_accuracy: 0.9669 - val_loss: 0.3459 - learning_rate: 1.0000e-05
# Epoch 98/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 103s 47ms/step - accuracy: 0.9027 - loss: 0.5303 - val_accuracy: 0.9679 - val_loss: 0.3436 - learning_rate: 1.0000e-05
# Epoch 99/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.9028 - loss: 0.5328 - val_accuracy: 0.9673 - val_loss: 0.3433 - learning_rate: 1.0000e-05
# Epoch 100/130
#  105/2197 ━━━━━━━━━━━━━━━━━━━━ 1:26 41ms/step - accuracy: 0.9066 - loss: 0.5245
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9031 - loss: 0.5299 - val_accuracy: 0.9677 - val_loss: 0.3417 - learning_rate: 1.0000e-05
# Epoch 101/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.9036 - loss: 0.5258 - val_accuracy: 0.9674 - val_loss: 0.3413 - learning_rate: 1.0000e-05
# Epoch 102/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 112s 51ms/step - accuracy: 0.9029 - loss: 0.5250 - val_accuracy: 0.9674 - val_loss: 0.3401 - learning_rate: 1.0000e-05
# Epoch 103/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.9060 - loss: 0.5195 - val_accuracy: 0.9679 - val_loss: 0.3394 - learning_rate: 1.0000e-05
# Epoch 104/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 112s 51ms/step - accuracy: 0.9052 - loss: 0.5211 - val_accuracy: 0.9682 - val_loss: 0.3382 - learning_rate: 1.0000e-05
# Epoch 105/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9074 - loss: 0.5159 - val_accuracy: 0.9684 - val_loss: 0.3369 - learning_rate: 1.0000e-05
# Epoch 106/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.9027 - loss: 0.5246 - val_accuracy: 0.9682 - val_loss: 0.3365 - learning_rate: 1.0000e-05
# Epoch 107/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.9064 - loss: 0.5112 - val_accuracy: 0.9681 - val_loss: 0.3354 - learning_rate: 1.0000e-05
# Epoch 108/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9050 - loss: 0.5158 - val_accuracy: 0.9672 - val_loss: 0.3354 - learning_rate: 1.0000e-05
# Epoch 109/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 104s 47ms/step - accuracy: 0.9056 - loss: 0.5158 - val_accuracy: 0.9684 - val_loss: 0.3337 - learning_rate: 1.0000e-05
# Epoch 110/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.9039 - loss: 0.5128 - val_accuracy: 0.9685 - val_loss: 0.3321 - learning_rate: 1.0000e-05
# Epoch 111/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.9075 - loss: 0.5104 - val_accuracy: 0.9689 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 112/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 113s 51ms/step - accuracy: 0.9064 - loss: 0.5088 - val_accuracy: 0.9692 - val_loss: 0.3304 - learning_rate: 1.0000e-05
# Epoch 113/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9083 - loss: 0.5079 - val_accuracy: 0.9689 - val_loss: 0.3299 - learning_rate: 1.0000e-05
# Epoch 114/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9090 - loss: 0.5036 - val_accuracy: 0.9692 - val_loss: 0.3291 - learning_rate: 1.0000e-05
# Epoch 115/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.9065 - loss: 0.5075 - val_accuracy: 0.9682 - val_loss: 0.3288 - learning_rate: 1.0000e-05
# Epoch 116/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 114s 52ms/step - accuracy: 0.9066 - loss: 0.5052 - val_accuracy: 0.9687 - val_loss: 0.3272 - learning_rate: 1.0000e-05
# Epoch 117/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9068 - loss: 0.5064 - val_accuracy: 0.9691 - val_loss: 0.3271 - learning_rate: 1.0000e-05
# Epoch 118/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 113s 51ms/step - accuracy: 0.9070 - loss: 0.5031 - val_accuracy: 0.9689 - val_loss: 0.3263 - learning_rate: 1.0000e-05
# Epoch 119/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.9090 - loss: 0.4963 - val_accuracy: 0.9690 - val_loss: 0.3256 - learning_rate: 1.0000e-05
# Epoch 120/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 112s 51ms/step - accuracy: 0.9085 - loss: 0.5016 - val_accuracy: 0.9689 - val_loss: 0.3254 - learning_rate: 1.0000e-05
# Epoch 121/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.9082 - loss: 0.4975 - val_accuracy: 0.9694 - val_loss: 0.3241 - learning_rate: 1.0000e-05
# Epoch 122/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9088 - loss: 0.4987 - val_accuracy: 0.9694 - val_loss: 0.3233 - learning_rate: 1.0000e-05
# Epoch 123/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - accuracy: 0.9096 - loss: 0.4944 - val_accuracy: 0.9700 - val_loss: 0.3236 - learning_rate: 1.0000e-05
# Epoch 124/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - accuracy: 0.9074 - loss: 0.4994 - val_accuracy: 0.9689 - val_loss: 0.3232 - learning_rate: 1.0000e-05
# Epoch 125/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.9097 - loss: 0.4888 - val_accuracy: 0.9693 - val_loss: 0.3220 - learning_rate: 1.0000e-05
# Epoch 126/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.9099 - loss: 0.4927 - val_accuracy: 0.9692 - val_loss: 0.3214 - learning_rate: 1.0000e-05
# Epoch 127/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.9113 - loss: 0.4873 - val_accuracy: 0.9692 - val_loss: 0.3208 - learning_rate: 1.0000e-05
# Epoch 128/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.9123 - loss: 0.4873 - val_accuracy: 0.9706 - val_loss: 0.3197 - learning_rate: 1.0000e-05
# Epoch 129/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.9093 - loss: 0.4915 - val_accuracy: 0.9695 - val_loss: 0.3197 - learning_rate: 1.0000e-05
# Epoch 130/130
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.9109 - loss: 0.4885 - val_accuracy: 0.9692 - val_loss: 0.3195 - learning_rate: 1.0000e-05

# %% [markdown]
# ### Fine-tuning for an extra 10 epoch

# %%
for layer in base_model.layers[-20:]:
    layer.trainable = True

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_fine = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=140,  #fine tune for extra 10 epoch
    initial_epoch =130 ,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 131/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 139s 56ms/step - accuracy: 0.8335 - loss: 0.7435 - val_accuracy: 0.9595 - val_loss: 0.3565 - learning_rate: 1.0000e-06
# Epoch 132/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.8860 - loss: 0.5784 - val_accuracy: 0.9639 - val_loss: 0.3432 - learning_rate: 1.0000e-06
# Epoch 133/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 113s 51ms/step - accuracy: 0.9037 - loss: 0.5172 - val_accuracy: 0.9656 - val_loss: 0.3288 - learning_rate: 1.0000e-06
# Epoch 134/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.9089 - loss: 0.4956 - val_accuracy: 0.9666 - val_loss: 0.3191 - learning_rate: 1.0000e-06
# Epoch 135/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 114s 52ms/step - accuracy: 0.9101 - loss: 0.4869 - val_accuracy: 0.9680 - val_loss: 0.3120 - learning_rate: 1.0000e-06
# Epoch 136/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 117s 53ms/step - accuracy: 0.9128 - loss: 0.4742 - val_accuracy: 0.9688 - val_loss: 0.3063 - learning_rate: 1.0000e-06
# Epoch 137/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.9149 - loss: 0.4656 - val_accuracy: 0.9696 - val_loss: 0.3019 - learning_rate: 1.0000e-06
# Epoch 138/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.9171 - loss: 0.4538 - val_accuracy: 0.9705 - val_loss: 0.2979 - learning_rate: 1.0000e-06
# Epoch 139/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 106s 48ms/step - accuracy: 0.9182 - loss: 0.4529 - val_accuracy: 0.9708 - val_loss: 0.2946 - learning_rate: 1.0000e-06
# Epoch 140/140
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.9199 - loss: 0.4393 - val_accuracy: 0.9714 - val_loss: 0.2916 - learning_rate: 1.0000e-06

# %% [markdown]
# ## Testing the model

# %%
def evaluate_model(model, dataset):
    results = model.evaluate(dataset)
    print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")

# Evaluate on validation set
evaluate_model(model, test_generator)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.9719 - loss: 0.2942
# Test Loss: 0.2925845980644226, Test Accuracy: 0.9711675643920898

# %%
class_names = list(train_generator.class_indices.keys())
print("Training dataset class names:", class_names)
# Out:
# Training dataset class names: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# %%
import os
test_dir_images = "/kaggle/input/new-plant-diseases-dataset/test/test"
test_images = sorted(os.listdir(test_dir_images))

# %%
import numpy as np
def predict_image(img_path, model):
    
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  
    
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions[0])
    confidence = np.max(predictions[0]) * 100
    
    return class_names[predicted_class], confidence

for img_name in test_images:
    img_path = os.path.join(test_dir_images, img_name)
    predicted_label = predict_image(img_path, model)
    print('Label:', img_name, ', Predicted:', predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Label: AppleCedarRust1.JPG , Predicted: ('Apple___Cedar_apple_rust', 99.85724687576294)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: AppleCedarRust2.JPG , Predicted: ('Apple___Cedar_apple_rust', 99.6794044971466)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: AppleCedarRust3.JPG , Predicted: ('Apple___Cedar_apple_rust', 99.87462759017944)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: AppleCedarRust4.JPG , Predicted: ('Apple___Cedar_apple_rust', 99.91925358772278)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: AppleScab1.JPG , Predicted: ('Apple___Apple_scab', 98.02191853523254)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: AppleScab2.JPG , Predicted: ('Apple___Apple_scab', 98.65032434463501)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: AppleScab3.JPG , Predicted: ('Apple___Apple_scab', 72.35761284828186)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: CornCommonRust1.JPG , Predicted: ('Corn_(maize)___Common_rust_', 99.77977275848389)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: CornCommonRust2.JPG , Predicted: ('Corn_(maize)___Common_rust_', 99.91551637649536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Label: CornCommonRust3.JPG , Predicted: ('Corn_(maize)___Common_rust_', 99.87882971763611)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: PotatoEarlyBlight1.JPG , Predicted: ('Potato___Early_blight', 99.95589852333069)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: PotatoEarlyBlight2.JPG , Predicted: ('Potato___Early_blight', 99.99908208847046)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: PotatoEarlyBlight3.JPG , Predicted: ('Potato___Early_blight', 59.72881317138672)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: PotatoEarlyBlight4.JPG , Predicted: ('Potato___Early_blight', 99.23623204231262)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: PotatoEarlyBlight5.JPG , Predicted: ('Potato___Early_blight', 99.87334609031677)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: PotatoHealthy1.JPG , Predicted: ('Potato___healthy', 99.91405010223389)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: PotatoHealthy2.JPG , Predicted: ('Potato___healthy', 99.96569156646729)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: TomatoEarlyBlight1.JPG , Predicted: ('Tomato___Early_blight', 80.8434545993805)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: TomatoEarlyBlight2.JPG , Predicted: ('Tomato___Late_blight', 58.771783113479614)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoEarlyBlight3.JPG , Predicted: ('Tomato___Early_blight', 64.6342933177948)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoEarlyBlight4.JPG , Predicted: ('Tomato___Bacterial_spot', 65.66248536109924)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: TomatoEarlyBlight5.JPG , Predicted: ('Tomato___Early_blight', 72.15616703033447)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoEarlyBlight6.JPG , Predicted: ('Tomato___Early_blight', 88.68516087532043)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoHealthy1.JPG , Predicted: ('Tomato___healthy', 97.208571434021)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoHealthy2.JPG , Predicted: ('Tomato___healthy', 67.24245548248291)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: TomatoHealthy3.JPG , Predicted: ('Tomato___healthy', 87.8223717212677)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: TomatoHealthy4.JPG , Predicted: ('Tomato___healthy', 96.73448204994202)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoYellowCurlVirus1.JPG , Predicted: ('Tomato___Tomato_Yellow_Leaf_Curl_Virus', 99.17054176330566)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoYellowCurlVirus2.JPG , Predicted: ('Tomato___Tomato_Yellow_Leaf_Curl_Virus', 99.98968839645386)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Label: TomatoYellowCurlVirus3.JPG , Predicted: ('Tomato___Tomato_Yellow_Leaf_Curl_Virus', 95.34807205200195)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: TomatoYellowCurlVirus4.JPG , Predicted: ('Tomato___Tomato_Yellow_Leaf_Curl_Virus', 99.82119798660278)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Label: TomatoYellowCurlVirus5.JPG , Predicted: ('Tomato___Tomato_Yellow_Leaf_Curl_Virus', 99.51633214950562)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Label: TomatoYellowCurlVirus6.JPG , Predicted: ('Tomato___Tomato_Yellow_Leaf_Curl_Virus', 99.9923825263977)

# %% [markdown]
# ### shows that out of 33 images, 31 is correct and 2 is wrong

# %%
import matplotlib.pyplot as plt


def plot_image_with_prediction(img_path, true_label, model):
    predicted_label, confidence = predict_image(img_path, model)
    
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
    
    plt.imshow(img)
    plt.axis('off')
    
    plt.title(f"True: {true_label}\nPredicted: {predicted_label} ({confidence:.2f}%)")
    plt.show()


test_image_path = os.path.join(test_dir_images, test_images[8])
true_label = "Corn_(maize)___Common_rust_"  # Replace with actual label for the image

plot_image_with_prediction(test_image_path, true_label, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
model.save("/kaggle/working/Plant_disease_detection_Mobilenetv3.h5")

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.tight_layout()
plt.show()

# %%
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))
    
download_file('/kaggle/working/Plant_disease_detection_Mobilenetv3.h5', 'out')
# Out:
# /kaggle/working/out.zip
